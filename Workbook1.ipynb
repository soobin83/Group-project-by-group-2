# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import csv

# Study data files
physical_activity_path = "Data/Physical_activity.csv"
suicide_path = "Data/Suicide.csv"
depression_by_state_path = "Data/Adults_depression_by_state_S.csv"
depression_by_ethnicity_path = "Data/Adults_depression_by_ethnicity_S.csv"

# %%
# Read the data and store into Pandas DataFrame
physical_activity = pd.read_csv(physical_activity_path)

# Display the data table for preview
physical_activity.head()
# Out:
#    Year LocationAbbr     Location  \
# 0  2020           US     National
# 1  2015           US     National
# 2  2015           GU         Guam
# 3  2015           PR  Puerto Rico
# 4  2015           GU         Guam
#
#                                             Question  Data_Value  \
# 0  Percent of adults who engage in no leisure-tim...        30.6
# 1  Percent of adults who achieve at least 300 min...        26.6
# 2  Percent of adults who achieve at least 150 min...        27.4
# 3  Percent of adults who engage in no leisure-tim...        38.1
# 4  Percent of adults who engage in no leisure-tim...        30.5
#
#    Low_Confidence  High_Confidence  Sample_Size Age(years) Gender  \
# 0            29.4             31.8      31255.0        NaN    NaN
# 1            25.6             27.6      30904.0        NaN    NaN
# 2            18.6             38.5        125.0        NaN    NaN
# 3            32.6             43.8        421.0        NaN    NaN
# ...

# %%
# Read the data
suicide = pd.read_csv(suicide_path)

# Display the data table for preview
suicide.head()
# Out:
#    YEAR STATE  RATE DEATHS
# 0  2020    AL  16.0    793
# 1  2020    AK  27.5    204
# 2  2020    AZ  17.6   1363
# 3  2020    AR  19.0    583
# 4  2020    CA  10.0   4144

# %%
# Read the data
depression_by_state = pd.read_csv(depression_by_state_path)

# Display the data table for preview
depression_by_state.head()
# Out:
#                                    Years  2011  2012  2013  2014  2015  2016  \
# 0  Percent of adults with depression (%)  0.18  0.18  0.19  0.19  0.19  0.17
# 1                               By State   NaN   NaN   NaN   NaN   NaN   NaN
# 2                            Alabama (%)  0.21  0.22  0.22  0.21  0.22  0.22
# 3                             Alaska (%)  0.17  0.17  0.16  0.16  0.16  0.14
# 4                            Arizona (%)  0.18  0.19  0.18  0.19  0.19  0.17
#
#    2017  2018  2019  2020
# 0  0.21  0.20  0.20  0.20
# 1   NaN   NaN   NaN   NaN
# 2  0.24  0.24  0.24  0.24
# 3  0.19  0.20  0.17  0.16
# 4  0.19  0.17  0.17  0.17

# %%
# Read the data
depression_by_ethnicity = pd.read_csv(depression_by_ethnicity_path)

# Display the data table for preview
depression_by_ethnicity.head()
# Out:
#                                                Years  2011  2012  2013  2014  \
# 0              Percent of adults with depression (%)  0.18  0.18  0.19  0.19
# 1                                  By Race/Ethnicity   NaN   NaN   NaN   NaN
# 2          American Indian or Alaskan Native, non...   NaN   NaN   NaN   NaN
# 3                            Asian, non-Hispanic (%)   NaN   NaN   NaN   NaN
# 4                            Black, non-Hispanic (%)  0.15  0.16  0.16  0.17
#
#    2015  2016  2017  2018  2019  2020
# 0  0.19  0.17  0.21  0.20  0.20  0.20
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2  0.27  0.28  0.28  0.26  0.26  0.27
# 3  0.08  0.09  0.11  0.10  0.08  0.10
# 4  0.16  0.16  0.17  0.18  0.16  0.17

# %%
# Combine the data into a single dataset
